# %% [markdown]
# ## Test de Wilcoxon

# %% [markdown]
# ## Codigo Test de Wilcoxon

# %% [markdown]
# 1-  "ninguno"        = cat("No hay correccion del data drifting"),
#
# 2 -  "rank_simple"    = drift_rank_simple(campos_monetarios),
#
# 3 -  "rank_cero_fijo" = drift_rank_cero_fijo(campos_monetarios),
#
# 4-  "deflacion"      = drift_deflacion(campos_monetarios),
#
# 5-  "dolar_blue"     = drift_dolarblue(campos_monetarios),
#
# 6-  "dolar_oficial"  = drift_dolaroficial(campos_monetarios),
#
# 7-  "UVA"            = drift_UVA(campos_monetarios),
#
# 8 -  "estandarizar"   = drift_estandarizar(campos_monetarios)

# %%
#OK: estandarizar le gana a UVA
UVA <- c(81827, 83987, 84403, 85815, 83738, 84403, 84901, 86562)
estandarizar <- c(94288, 93291, 91091, 88390, 85981, 90135, 100851, 96199)

wilcox.test(
  estandarizar,
  UVA,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and UVA
# V = 36, p-value = 0.003906
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# p=0.003906<0.05 se rechaza H0, estandarizar es mejor que UVA.

# %%
#OK: estandarizar le gana a dolar_oficial
dolar_oficial <- c(87642, 87725, 93208, 80581, 91962, 88141, 84569, 87393)
estandarizar <- c(94288, 91091, 88390, 85981, 90135, 100851, 96199, 92045)

wilcox.test(
  estandarizar,
  dolar_oficial,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and dolar_oficial
# V = 31, p-value = 0.03906
# alternative hypothesis: true location shift is greater than 0

# %%
# pendiente
dolar_oficial <- c(350000, 355000, 370000, 368000, 360000)
UVA <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
#OK: estandarizar le gana a dolar blue
dolar_blue <- c(82326, 81910, 89885, 80664, 87476, 88058, 84319, 81993)
estandarizar <- c(94288, 93291, 91091, 88390, 85981, 100851, 96199, 92045)

wilcox.test(
  estandarizar,
  dolar_blue,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and dolar_blue
# V = 34, p-value = 0.01172
# alternative hypothesis: true location shift is greater than 0

# %%
# VER no es concluyente, agregar semillas
dolar_blue <- c(82326, 81910, 89885, 80664, 87476, 88058, 84319)
UVA <- c(81827, 83987, 84403, 85815, 83738, 84901, 86562)

wilcox.test(
  dolar_blue,
  UVA,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  dolar_blue and UVA
# V = 17, p-value = 0.3438
# alternative hypothesis: true location shift is greater than 0

# %%
dolar_blue <- c(82326, 81910, 89885, 80664, 87476, 88058, 84319)
dolar_oficial <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
#Ver no concluyente, agregar semillas
deflacion <- c(87642, 84236, 86562, 90550, 87559, 88889, 94704, 90301)
estandarizar <- c(94288, 91091, 88390, 85981, 90135, 100851, 96199, 92045)

wilcox.test(
  estandarizar,
  deflacion,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and deflacion
# V = 31, p-value = 0.03906
# alternative hypothesis: true location shift is greater than 0

# %%
deflacion <- c(87559, 87725, 88889, 94704, 84236, 90550)
UVA <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
deflacion <- c(87559, 87725, 88889, 94704, 84236, 90550)
dolar_oficial <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
deflacion <- c(87559, 87725, 88889, 94704, 84236, 90550)
dolar_blue <- c(84236, 88058, 84319, 81993, 80664, 87476)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
#OK: gana estandarizar
rank_cero_fijo <- c(92128, 82243, 84236, 82243, 88639, 81412, 84153)
estandarizar <- c(94288, 88390, 85981, 90135, 100851, 96199, 92045)

wilcox.test(
  estandarizar,
  rank_cero_fijo,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and rank_cero_fijo
# V = 28, p-value = 0.007812
# alternative hypothesis: true location shift is greater than 0

# %%
rank_cero_fijo <- c(82243, 81412, 84153, 82243, 84236)
UVA <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
rank_cero_fijo <- c(82243, 81412, 84153, 82243, 84236)
dolar_oficial <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
rank_cero_fijo <- c(82243, 81412, 84153, 82243, 84236)
dolar_blue <- c(84236, 88058, 84319, 81993, 80664, 87476)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
rank_cero_fijo <- c(82243, 81412, 84153, 82243, 84236)
deflacion <- c(87559, 87725, 88889, 94704, 84236, 90550)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
#OK: estandarizar es mejor que rank_simple
rank_simple <- c(86729, 84652, 83489, 87975, 91962, 84486, 77092)
estandarizar <- c(94288, 93291, 91091, 88390, 85981, 90135, 92045)

wilcox.test(
  estandarizar,
  rank_simple,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and rank_simple
# V = 25, p-value = 0.03906
# alternative hypothesis: true location shift is greater than 0

# %%
rank_simple <- c(84486, 80249, 77092, 86729, 84652, 83489, 87975, 91962)
UVA <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
rank_simple <- c(84486, 80249, 77092, 86729, 84652, 83489, 87975, 91962)
dolar_oficial <- c(360000, 362000, 365000, 375000, 380000)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
#VER: no concluye
rank_simple <- c(86729, 83489, 87975, 91962, 80249, 77092)
dolar_blue <- c(84236, 89885, 80664, 87476, 84236, 81993)

wilcox.test(
  dolar_blue,
  rank_simple,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  dolar_blue and rank_simple
# V = 11, p-value = 0.5
# alternative hypothesis: true location shift is greater than 0

# %%
rank_simple <- c(86729, 87975, 91962, 84486, 80249, 89719, 77092)
deflacion <- c(87559, 87725, 88889, 94704, 84236, 90550)

wilcox.test(
  metodo2,
  metodo1,
  paired = TRUE,
  alternative = "greater"
)

# %%
#Ver : no concluyente, se necesitan mas semillas
rank_simple <- c(86729, 87975, 91962, 84486, 80249, 89719, 77092)
rank_cero_fijo <- c(92128, 82243, 84236, 82243, 89470, 88639, 84153)

wilcox.test(
  rank_cero_fijo,
  rank_simple,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  rank_cero_fijo and rank_simple
# V = 15, p-value = 0.4687
# alternative hypothesis: true location shift is greater than 0

# %%
#OK: estandarizar es mejor que ninguno pero no tan contundente como al compararlo con UVA
ninguno <- c(87144, 88556, 87809, 86064, 85649, 90965, 88224, 87061)
estandarizar <- c(94288, 93291, 91091, 88390, 85981, 90135, 100851, 96199)

wilcox.test(
  estandarizar,
  ninguno,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  estandarizar and ninguno
# V = 34, p-value = 0.01172
# alternative hypothesis: true location shift is greater than 0

# %%
# OK: ninguno mejor que uva
ninguno <- c(87144, 88556, 87809, 86064, 85649, 90965, 88224, 87061)
UVA <- c(81827, 83987, 84403, 85815, 83738, 84403, 84901, 86562)

wilcox.test(
  ninguno,
  UVA,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  ninguno and UVA
# V = 36, p-value = 0.003906
# alternative hypothesis: true location shift is greater than 0

# %%
#VER: no concluyente se necesitan mas semillas, tengo 9
ninguno <- c(87144, 87809, 86064, 85649, 90965, 83489, 88224, 87061, 89304)
dolar_oficial <- c(87642, 87725, 93208, 80581, 91962, 91048, 88141, 84569, 87393)

wilcox.test(
  ninguno,
  dolar_oficial,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  ninguno and dolar_oficial
# V = 21, p-value = 0.5898
# alternative hypothesis: true location shift is greater than 0

# %%
#VER: no conluye tenemos 9 semillas
ninguno <- c(87144, 88556, 87809, 86064, 85649, 83489, 88224, 87061, 89304)
dolar_blue <- c(84236, 81910, 89885, 80664, 87476, 84236, 88058, 84319, 81993)

wilcox.test(
  ninguno,
  dolar_blue,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  ninguno and dolar_blue
# V = 36, p-value = 0.06445
# alternative hypothesis: true location shift is greater than 0

# %%
# VER: no concluyente completar semillas hay 9 semillas
ninguno <- c(87144, 87809, 86064, 85649, 90965, 83489, 88224, 87061, 89304)
deflacion <- c(76843, 84236, 86562, 90550, 87559, 87725, 88889, 94704, 90301)

wilcox.test(
  deflacion,
  ninguno,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  deflacion and ninguno
# V = 27, p-value = 0.3262
# alternative hypothesis: true location shift is greater than 0

# %%
# VER: no concluyente completar semillas rank cero fijo hay 8 semillas
ninguno <- c(87144, 86064, 85649, 90965,83489, 88224, 87061, 89304)
rank_cero_fijo <- c(92128, 82243, 84236, 82243, 89470, 88639, 81412, 84153)

wilcox.test(
  ninguno,
  rank_cero_fijo,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  ninguno and rank_cero_fijo
# V = 24, p-value = 0.2305
# alternative hypothesis: true location shift is greater than 0

# %%
#VER:  agregar semillas!! no concluye tenemos 9 semillas
ninguno <- c(87144, 88556, 87809, 86064, 85649, 90965, 83489, 88224, 89304)
rank_simple <- c(86729, 84652, 83489, 87975, 91962, 84486, 80249, 89719, 77092)

wilcox.test(
  ninguno,
  rank_simple,
  paired = TRUE,
  alternative = "greater"
)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  ninguno and rank_simple
# V = 33, p-value = 0.125
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# El resultado:
#
# V = 8
# p-value = 0.7187
# alternative hypothesis: true location shift is greater than 0
#
# significa que no hay evidencia estadísticamente significativa para afirmar que rank_simple tenga una ganancia mayor que ninguno.
#
# Con un nivel de significancia habitual de 5%:
#
# $$ p = 0.7187 > 0.05 $$
#
# por lo tanto:
#
# No rechazás H₀.

# %% [markdown]
# ## Aca ternima test de Wilcoxon.
